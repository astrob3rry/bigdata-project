# %%
#from pyspark.sql import Row
#import sys
#from pyspark.sql import SparkSession

#from itertools import islice
#spark = SparkSession.builder.appName("t1").getOrCreate()
#sc = spark.sparkContext

# %% [markdown]
# # Part1 generating data

# %%
import pandas as pd
import pathlib
import datamart_geo
import datamart_profiler
import os
import json
path = pathlib.Path().absolute()

directory = os.path.join("c:\\",path) # if the file is not in c:\\, change it
dataDirectory = os.path.join(path, "Datasets") #make sure that all the csv files are in the directory named Datasets
resultDirectory = os.path.join(path, "result") #make sure that you have created the folder result

# %%
#print all the filenames
for root,dirs,files in os.walk(dataDirectory):
    for file in files:
        if file.endswith(".csv"):
            print(file)
# Out:
# 2010_2016_School_Safety_Report.csv
# 2015_Green_Taxi_Trip_Data.csv
# 2015_Street_Tree_Census_Tree_Data.csv
# 311_Service_Requests_for_2009.csv
# ACS_Community_Partners.csv
# Active_Projects_Under_Construction.csv
# Asbestos_Control_Program__ACP7_.csv
# Board_of_Standards_and_Appeals__BSA__Applications_Status.csv
# Borough_Enrollment_Offices.csv
# Buildings_Selected_for_the_Alternative_Enforcement_Program__AEP_.csv
# Buildings_Subject_to_HPD_Jurisdiction.csv
# Bureau_of_Fire_Prevention_-_Active_Violation_Orders.csv
# Bureau_of_Fire_Prevention_-_Inspections.csv
# CATS_Permits.csv
# Center___Service_Locations.csv
# Charges.csv
# City-owned_sites_that_are_available_and_potentially_suitable_for_urban_agriculture__Local_Law_46_of_2018_.csv
# Construction_Demolition_Registrants.csv
# Consumer_Services_Mediated_Complaints.csv
# Council_Members.csv
# CURRENT_BASES.csv
# DCLA_Cultural_Organizations.csv
# Deed_Restriction_Database.csv
# Department_for_the_Aging__DFTA__All_Contracted_Providers.csv
# Directory_Of_Job_Centers.csv
# Directory_of_NYCHA_Community_Facilities.csv
# Directory_of_SNAP_Centers.csv
# Directory_Of_Toilets_In_Public_Parks.csv
# DOB_Cellular_Antenna_Filings.csv
# DOB_Certificate_Of_Occupancy.csv
# DOB_Complaints_Received.csv
# DOB_ECB_Violations.csv
# DOB_Job_Application_Filings.csv
# DOB_NOW__Build___Job_Application_Filings.csv
# DOB_NOW__Safety___Facades_Compliance_Filings.csv
# DOB_NOW_Build_Approved_Permits.csv
# DOB_Stalled_Construction_Sites.csv
# DOF__Condominium_comparable_rental_income___Manhattan_-_FY_2010_2011.csv
# DOHMH_Childcare_Center_Inspections.csv
# DOHMH_Cooling_Tower_Data.csv
# DOHMH_Dog_Bite_Data.csv
# DOHMH_Farmers_Markets.csv
# DOHMH_Indoor_Environmental_Complaints.csv
# DOHMH_New_York_City_Restaurant_Inspection_Results.csv
# Drinking_Water_Quality_Distribution_Monitoring_Data.csv
# DSNY_Graffiti_Tracking.csv
# DYCD_after_school_programs_OSY_out_of_school_youth_employment_programs.csv
# Emergency_Response_Incidents.csv
# Energy_and_Water_Data_Disclosure_for_Local_Law_84_2012__Data_for_Calendar_Year_2011_.csv
# Energy_and_Water_Data_Disclosure_for_Local_Law_84_2013__Data_for_Calendar_Year_2012_.csv
# Energy_and_Water_Data_Disclosure_for_Local_Law_84_2015__Data_for_Calendar_Year_2014_.csv
# Energy_and_Water_Data_Disclosure_for_Local_Law_84_2017__Data_for_Calendar_Year_2016_.csv
# Energy_Efficiency_Projects.csv
# Evictions.csv
# Facilities_Database.csv
# FDNY_Firehouse_Listing.csv
# FDNY_Monthly_Response_Times.csv
# Film_Permits.csv
# Financial_Empowerment_Centers.csv
# For_Hire_Vehicles_FHV_Active.csv
# GED_Plus_Locations.csv
# Greenbook.csv
# Heating_Gas_Consumption_And_Cost__2010_-__2020_.csv
# Historical_Medallion__Vehicles_-_Authorized-009.csv
# HIV_AIDS_Diagnoses_by_Neighborhood__Sex__and_Race_Ethnicity.csv
# Housing_Maintenance_Code_Complaints.csv
# Housing_Maintenance_Code_Violations-010.csv
# Housing_New_York_Units_by_Building.csv
# IDNYC_Locations.csv
# Incidents_Responded_to_by_Fire_Companies.csv
# Inspections.csv
# IPIS__Integrated_Property_Information_System_.csv
# Latin_Cultural_Organizations.csv
# Legally_Operating_Businesses.csv
# License_Applications.csv
# LinkNYC_Locations.csv
# Local_Law_44_Disqualified_List.csv
# M_WBE__LBE__and_EBE_Certified_Business_List.csv
# Mobile_Telecommunications_Franchise_Pole_Reservation_Locations.csv
# Motor_Vehicle_Collisions_Crashes.csv
# Multiple_Dwelling_Registrations.csv
# Natural_Gas_Consumption_by_ZIP_Code_-_2010.csv
# New_York_City_Council_Discretionary_Funding__2009-2013_.csv
# New_York_City_Council_Discretionary_Funding__2013_.csv
# New_York_City_Locations_Providing_Seasonal_Flu_Vaccinations.csv
# NYC_Citywide_Annualized_Calendar_Sales_Update.csv
# NYC_Community_Based_Organizations.csv
# NYC_Council_Constituent_Services.csv
# NYC_Fire_Department_Building_Vacate_List.csv
# NYC_Greenthumb_Community_Gardens.csv
# NYC_Health_Hospitals_patient_care_locations_2011.csv
# NYC_Municipal_Building_Energy_Benchmarking_Results.csv
# NYC_REACH_Members.csv
# NYC_Service__Volunteer_Opportunities__Historical_.csv
# NYC_Wi-Fi_Hotspot_Locations.csv
# NYC_Women_s_Resource_Network_Database.csv
# NYCDEP_Recreation_Area_Maps.csv
# NYCHA_Facilities_and_Service_Centers.csv
# NYPD_Arrest_Data_Year_to_Date_.csv
# NYPD_Arrests_Data__Historic_.csv
# NYPD_Complaint_Data_Current__Year_To_Date_.csv
# NYPD_Complaint_Data_Historic-008.csv
# NYPD_Criminal_Court_Summons__Historic_.csv
# NYPD_Criminal_Court_Summons_Incident_Level_Data__Year_To_Date_.csv
# NYPD_Shooting_Incident_Data__Historic_.csv
# Open_Market_Order__OMO__Charges.csv
# Open_Restaurant_Applications.csv
# Open_Streets_Locations.csv
# Order_to_Repair_Vacate_Orders.csv
# Parking_Violations_Issued_-_Fiscal_Year_2015-011.csv
# Participatory_Budgeting_Projects.csv
# Public_Recycling_Bins.csv
# Queens_Library_Branches.csv
# Real_Property_Income_and_Expense_Form_non-compliance_list.csv
# Recognized_Shop_Healthy_Stores.csv
# Revised_Notice_of_Property_Value__RNOPV_.csv
# Rodent_Inspection.csv
# Routes.csv
# SBS_ICAP_Contract_Opportunities.csv
# Self_Hauler_Registrants.csv
# Shelter_Repair_Scorecard.csv
# Sidewalk_Caf__Licenses_and_Applications.csv
# Street_Closures_due_to_construction_activities_by_Block.csv
# Suitability_of_City-Owned_and_Leased_Property_for_Urban_Agriculture__LL_48_of_2011_.csv
# Tax_Lien_Sale_Lists.csv
# Taxicab_Partition_Manufacturers_and_Installers__Dataset_.csv
# TLC_Approved_LabCorp_Patient_Services_Drug_Test_Locations__Dataset_.csv
# TLC_Driver_Education_24_Hour_Course_Providers__Dataset_.csv
# Tobacco_Retail_Dealer_and_Electronic_Cigarette_Retail_Dealer_Caps_by_Community_District.csv
# Trade_Waste_Broker_Registrants.csv
# Trade_Waste_Hauler_Licensees.csv
# Transportation_Sites.csv
# Universal_Pre-K__UPK__School_Locations.csv
# Voting_Poll_Sites.csv
# Water_Consumption_And_Cost__2013_-_2020_.csv
# Wholesale_Markets.csv
# WiredNYC___All_Buildings_Data.csv
# Workforce1_Job_Listing.csv

# %%
# read all the csv files, process them with datamart and then save it to txt files
# this step will skip files which already been processed and saved, so feel free to interrupte and continue at any time
# this cell may take several hours to run if you do not have anythin in the "result" folder 

counter = 0
df = []
for root,dirs,files in os.walk(dataDirectory):
    for file in files:
        if file.endswith(".csv"):
            done = False
            for root,dirs,files in os.walk(directory):
                if (file+".txt") in files:
                    print("skip " + file)
                    done = True
            if done == False:
                print("start loading...")
                tempd = datamart_profiler.process_dataset(dataDirectory + "/" + file)
                df.append(tempd)
                with open("result/" + file +".txt", 'w') as outfile:
                    json.dump(tempd, outfile)
                print(file)
        counter +=1
# Out:
# skip 2010_2016_School_Safety_Report.csv
# skip 2015_Green_Taxi_Trip_Data.csv
# skip 2015_Street_Tree_Census_Tree_Data.csv
# skip 311_Service_Requests_for_2009.csv
# skip ACS_Community_Partners.csv
# skip Active_Projects_Under_Construction.csv
# skip Asbestos_Control_Program__ACP7_.csv
# skip Board_of_Standards_and_Appeals__BSA__Applications_Status.csv
# skip Borough_Enrollment_Offices.csv
# skip Buildings_Selected_for_the_Alternative_Enforcement_Program__AEP_.csv
# skip Buildings_Subject_to_HPD_Jurisdiction.csv
# skip Bureau_of_Fire_Prevention_-_Active_Violation_Orders.csv
# skip Bureau_of_Fire_Prevention_-_Inspections.csv
# skip CATS_Permits.csv
# skip Center___Service_Locations.csv
# skip Charges.csv
# skip City-owned_sites_that_are_available_and_potentially_suitable_for_urban_agriculture__Local_Law_46_of_2018_.csv
# skip Construction_Demolition_Registrants.csv
# skip Consumer_Services_Mediated_Complaints.csv
# skip Council_Members.csv
# skip CURRENT_BASES.csv
# skip DCLA_Cultural_Organizations.csv
# skip Deed_Restriction_Database.csv
# skip Department_for_the_Aging__DFTA__All_Contracted_Providers.csv
# skip Directory_Of_Job_Centers.csv
# skip Directory_of_NYCHA_Community_Facilities.csv
# skip Directory_of_SNAP_Centers.csv
# skip Directory_Of_Toilets_In_Public_Parks.csv
# skip DOB_Cellular_Antenna_Filings.csv
# skip DOB_Certificate_Of_Occupancy.csv
# skip DOB_Complaints_Received.csv
# skip DOB_ECB_Violations.csv
# skip DOB_Job_Application_Filings.csv
# skip DOB_NOW__Build___Job_Application_Filings.csv
# skip DOB_NOW__Safety___Facades_Compliance_Filings.csv
# skip DOB_NOW_Build_Approved_Permits.csv
# skip DOB_Stalled_Construction_Sites.csv
# skip DOF__Condominium_comparable_rental_income___Manhattan_-_FY_2010_2011.csv
# skip DOHMH_Childcare_Center_Inspections.csv
# skip DOHMH_Cooling_Tower_Data.csv
# skip DOHMH_Dog_Bite_Data.csv
# skip DOHMH_Farmers_Markets.csv
# skip DOHMH_Indoor_Environmental_Complaints.csv
# skip DOHMH_New_York_City_Restaurant_Inspection_Results.csv
# skip Drinking_Water_Quality_Distribution_Monitoring_Data.csv
# skip DSNY_Graffiti_Tracking.csv
# skip DYCD_after_school_programs_OSY_out_of_school_youth_employment_programs.csv
# skip Emergency_Response_Incidents.csv
# skip Energy_and_Water_Data_Disclosure_for_Local_Law_84_2012__Data_for_Calendar_Year_2011_.csv
# skip Energy_and_Water_Data_Disclosure_for_Local_Law_84_2013__Data_for_Calendar_Year_2012_.csv
# skip Energy_and_Water_Data_Disclosure_for_Local_Law_84_2015__Data_for_Calendar_Year_2014_.csv
# skip Energy_and_Water_Data_Disclosure_for_Local_Law_84_2017__Data_for_Calendar_Year_2016_.csv
# skip Energy_Efficiency_Projects.csv
# skip Evictions.csv
# skip Facilities_Database.csv
# skip FDNY_Firehouse_Listing.csv
# skip FDNY_Monthly_Response_Times.csv
# skip Film_Permits.csv
# skip Financial_Empowerment_Centers.csv
# skip For_Hire_Vehicles_FHV_Active.csv
# skip GED_Plus_Locations.csv
# skip Greenbook.csv
# skip Heating_Gas_Consumption_And_Cost__2010_-__2020_.csv
# skip Historical_Medallion__Vehicles_-_Authorized-009.csv
# skip HIV_AIDS_Diagnoses_by_Neighborhood__Sex__and_Race_Ethnicity.csv
# skip Housing_Maintenance_Code_Complaints.csv
# skip Housing_Maintenance_Code_Violations-010.csv
# skip Housing_New_York_Units_by_Building.csv
# skip IDNYC_Locations.csv
# skip Incidents_Responded_to_by_Fire_Companies.csv
# skip Inspections.csv
# skip IPIS__Integrated_Property_Information_System_.csv
# skip Latin_Cultural_Organizations.csv
# skip Legally_Operating_Businesses.csv
# skip License_Applications.csv
# skip LinkNYC_Locations.csv
# skip Local_Law_44_Disqualified_List.csv
# skip M_WBE__LBE__and_EBE_Certified_Business_List.csv
# skip Mobile_Telecommunications_Franchise_Pole_Reservation_Locations.csv
# skip Motor_Vehicle_Collisions_Crashes.csv
# skip Multiple_Dwelling_Registrations.csv
# skip Natural_Gas_Consumption_by_ZIP_Code_-_2010.csv
# skip New_York_City_Council_Discretionary_Funding.csv
# skip New_York_City_Council_Discretionary_Funding__2009-2013_.csv
# skip New_York_City_Council_Discretionary_Funding__2013_.csv
# skip New_York_City_Locations_Providing_Seasonal_Flu_Vaccinations.csv
# skip NYC_Citywide_Annualized_Calendar_Sales_Update.csv
# skip NYC_Community_Based_Organizations.csv
# skip NYC_Council_Constituent_Services.csv
# skip NYC_Fire_Department_Building_Vacate_List.csv
# skip NYC_Greenthumb_Community_Gardens.csv
# skip NYC_Health_Hospitals_patient_care_locations_2011.csv
# skip NYC_Municipal_Building_Energy_Benchmarking_Results.csv
# skip NYC_REACH_Members.csv
# skip NYC_Service__Volunteer_Opportunities__Historical_.csv
# skip NYC_Wi-Fi_Hotspot_Locations.csv
# skip NYC_Women_s_Resource_Network_Database.csv
# skip NYCDEP_Recreation_Area_Maps.csv
# skip NYCHA_Facilities_and_Service_Centers.csv
# skip NYPD_Arrest_Data_Year_to_Date_.csv
# skip NYPD_Arrests_Data__Historic_.csv
# skip NYPD_Complaint_Data_Current__Year_To_Date_.csv
# skip NYPD_Complaint_Data_Historic-008.csv
# skip NYPD_Criminal_Court_Summons__Historic_.csv
# skip NYPD_Criminal_Court_Summons_Incident_Level_Data__Year_To_Date_.csv
# skip NYPD_Shooting_Incident_Data__Historic_.csv
# skip Open_Market_Order__OMO__Charges.csv
# skip Open_Restaurant_Applications.csv
# skip Open_Streets_Locations.csv
# skip Order_to_Repair_Vacate_Orders.csv
# skip Parking_Violations_Issued_-_Fiscal_Year_2015-011.csv
# skip Participatory_Budgeting_Projects.csv
# skip Public_Recycling_Bins.csv
# skip Queens_Library_Branches.csv
# skip Real_Property_Income_and_Expense_Form_non-compliance_list.csv
# skip Recognized_Shop_Healthy_Stores.csv
# skip Revised_Notice_of_Property_Value__RNOPV_.csv
# skip Rodent_Inspection.csv
# skip Routes.csv
# skip SBS_ICAP_Contract_Opportunities.csv
# skip Self_Hauler_Registrants.csv
# skip Shelter_Repair_Scorecard.csv
# skip Sidewalk_Caf__Licenses_and_Applications.csv
# skip Street_Closures_due_to_construction_activities_by_Block.csv
# skip Suitability_of_City-Owned_and_Leased_Property_for_Urban_Agriculture__LL_48_of_2011_.csv
# skip Tax_Lien_Sale_Lists.csv
# skip Taxicab_Partition_Manufacturers_and_Installers__Dataset_.csv
# skip TLC_Approved_LabCorp_Patient_Services_Drug_Test_Locations__Dataset_.csv
# skip TLC_Driver_Education_24_Hour_Course_Providers__Dataset_.csv
# skip Tobacco_Retail_Dealer_and_Electronic_Cigarette_Retail_Dealer_Caps_by_Community_District.csv
# skip Trade_Waste_Broker_Registrants.csv
# skip Trade_Waste_Hauler_Licensees.csv
# skip Transportation_Sites.csv
# skip Universal_Pre-K__UPK__School_Locations.csv
# skip Voting_Poll_Sites.csv
# skip Water_Consumption_And_Cost__2013_-_2020_.csv
# skip Wholesale_Markets.csv
# skip WiredNYC___All_Buildings_Data.csv
# skip Workforce1_Job_Listing.csv

# %%
#count the number of dataset which contains lat lon based on semantic types
counter = 0
djson = []
filenames = []
for root,dirs,files in os.walk(resultDirectory):
    for file in files:
        if file.endswith(".txt"):
            with open("result/" + file) as f:
                tempdjson = json.load(f)
                djson.append(tempdjson) 
                filenames.append(file) #match filename with djson content
def check_lat(col_list):
    for content in col_list:
        if 'semantic_types' in content:
            if content['semantic_types'] ==['http://schema.org/latitude']:
                return True
    return False
def check_lon(col_list):
    for content in col_list:
        if 'semantic_types' in content:
            if content['semantic_types'] ==['http://schema.org/longitude']:
                return True
    return False
num_data = len(djson)
counter = 0
latlon_data = pd.DataFrame({'latlon' : []})
for i in range(num_data):
    if check_lat(djson[i]["columns"]) and check_lon(djson[i]["columns"]):
        counter +=1
        latlon_data.loc[filenames[i]] = [1]
    elif check_lat(djson[i]["columns"]) or check_lon(djson[i]["columns"]):
        print(djson[i])
    else:
        latlon_data.loc[filenames[i]] = [0]
        
counter
# Out:
# 94

# %%
#save the information of column names into a csv file
#1 means this csv has this column
#0 means this csv do not have this column

names = []
for i in range(num_data):
    for content in djson[i]["columns"]:
        name = content["name"].lower()
        if name not in names:
            names.append(name)      
names = sorted(names)
zeros = [0]*len(names)
df_names = pd.DataFrame(columns = names)
for i in range(num_data):
    df_names.loc[filenames[i]] = zeros
    for content in djson[i]["columns"]:
        name = content["name"].lower()
        df_names.loc[filenames[i]][name] = 1

# %%
df_names.to_csv("column_names.csv")

# %%
df_names
# Out:
#                                                   comparable rental 1 boro-block-lot  \
# 2010_2016_School_Safety_Report.csv.txt                                             0
# 2015_Green_Taxi_Trip_Data.csv.txt                                                  0
# 2015_Street_Tree_Census_Tree_Data.csv.txt                                          0
# 311_Service_Requests_for_2009.csv.txt                                              0
# ACS_Community_Partners.csv.txt                                                     0
# ...                                                                              ...
# Voting_Poll_Sites.csv.txt                                                          0
# Water_Consumption_And_Cost__2013_-_2020_.csv.txt                                   0
# Wholesale_Markets.csv.txt                                                          0
# WiredNYC___All_Buildings_Data.csv.txt                                              0
# Workforce1_Job_Listing.csv.txt                                                     0
#
#                                                   consumption (gj)   \
# 2010_2016_School_Safety_Report.csv.txt                            0
# 2015_Green_Taxi_Trip_Data.csv.txt                                 0
# 2015_Street_Tree_Census_Tree_Data.csv.txt                         0
# 311_Service_Requests_for_2009.csv.txt                             0
# ACS_Community_Partners.csv.txt                                    0
# ...                                                             ...
# Voting_Poll_Sites.csv.txt                                         0
# Water_Consumption_And_Cost__2013_-_2020_.csv.txt                  0
# Wholesale_Markets.csv.txt                                         0
# WiredNYC___All_Buildings_Data.csv.txt                             0
# Workforce1_Job_Listing.csv.txt                                    0
#
#                                                   consumption (therms)   \
# 2010_2016_School_Safety_Report.csv.txt                                0
# 2015_Green_Taxi_Trip_Data.csv.txt                                     0
# 2015_Street_Tree_Census_Tree_Data.csv.txt                             0
# 311_Service_Requests_for_2009.csv.txt                                 0
# ACS_Community_Partners.csv.txt                                        0
# ...                                                                 ...
# Voting_Poll_Sites.csv.txt                                             0
# Water_Consumption_And_Cost__2013_-_2020_.csv.txt                      0
# Wholesale_Markets.csv.txt                                             0
# WiredNYC___All_Buildings_Data.csv.txt                                 0
# Workforce1_Job_Listing.csv.txt                                        0
#
#                                                  # days # isps  \
# 2010_2016_School_Safety_Report.csv.txt                0      0
# 2015_Green_Taxi_Trip_Data.csv.txt                     0      0
# 2015_Street_Tree_Census_Tree_Data.csv.txt             0      0
# 311_Service_Requests_for_2009.csv.txt                 0      0
# ACS_Community_Partners.csv.txt                        0      0
# ...                                                 ...    ...
# Voting_Poll_Sites.csv.txt                             0      0
# Water_Consumption_And_Cost__2013_-_2020_.csv.txt      1      0
# Wholesale_Markets.csv.txt                             0      0
# WiredNYC___All_Buildings_Data.csv.txt                 0      1
# Workforce1_Job_Listing.csv.txt                        0      0
#
#                                                  # of b/c violations at start  \
# 2010_2016_School_Safety_Report.csv.txt                                      0
# 2015_Green_Taxi_Trip_Data.csv.txt                                           0
# 2015_Street_Tree_Census_Tree_Data.csv.txt                                   0
# 311_Service_Requests_for_2009.csv.txt                                       0
# ACS_Community_Partners.csv.txt                                              0
# ...                                                                       ...
# Voting_Poll_Sites.csv.txt                                                   0
# Water_Consumption_And_Cost__2013_-_2020_.csv.txt                            0
# Wholesale_Markets.csv.txt                                                   0
# WiredNYC___All_Buildings_Data.csv.txt                                       0
# Workforce1_Job_Listing.csv.txt                                              0
#
#                                                  # of carriers # schools  \
# 2010_2016_School_Safety_Report.csv.txt                       0         1
# 2015_Green_Taxi_Trip_Data.csv.txt                            0         0
# 2015_Street_Tree_Census_Tree_Data.csv.txt                    0         0
# 311_Service_Requests_for_2009.csv.txt                        0         0
# ACS_Community_Partners.csv.txt                               0         0
# ...                                                        ...       ...
# Voting_Poll_Sites.csv.txt                                    0         0
# Water_Consumption_And_Cost__2013_-_2020_.csv.txt             0         0
# Wholesale_Markets.csv.txt                                    0         0
# WiredNYC___All_Buildings_Data.csv.txt                        1         0
# Workforce1_Job_Listing.csv.txt                               0         0
#
#                                                  1-br units 2-br units  ...  \
# 2010_2016_School_Safety_Report.csv.txt                    0          0  ...
# 2015_Green_Taxi_Trip_Data.csv.txt                         0          0  ...
# 2015_Street_Tree_Census_Tree_Data.csv.txt                 0          0  ...
# 311_Service_Requests_for_2009.csv.txt                     0          0  ...
# ACS_Community_Partners.csv.txt                            0          0  ...
# ...                                                     ...        ...  ...
# Voting_Poll_Sites.csv.txt                                 0          0  ...
# Water_Consumption_And_Cost__2013_-_2020_.csv.txt          0          0  ...
# Wholesale_Markets.csv.txt                                 0          0  ...
# WiredNYC___All_Buildings_Data.csv.txt                     0          0  ...
# Workforce1_Job_Listing.csv.txt                            0          0  ...
#
#                                                  zone zone dist 1 zone dist 2  \
# 2010_2016_School_Safety_Report.csv.txt              0           0           0
# 2015_Green_Taxi_Trip_Data.csv.txt                   0           0           0
# 2015_Street_Tree_Census_Tree_Data.csv.txt           0           0           0
# 311_Service_Requests_for_2009.csv.txt               0           0           0
# ACS_Community_Partners.csv.txt                      0           0           0
# ...                                               ...         ...         ...
# Voting_Poll_Sites.csv.txt                           0           0           0
# Water_Consumption_And_Cost__2013_-_2020_.csv.txt    0           0           0
# Wholesale_Markets.csv.txt                           0           0           0
# WiredNYC___All_Buildings_Data.csv.txt               0           0           0
# Workforce1_Job_Listing.csv.txt                      0           0           0
#
#                                                  zoning dist1 zoning dist2  \
# 2010_2016_School_Safety_Report.csv.txt                      0            0
# 2015_Green_Taxi_Trip_Data.csv.txt                           0            0
# 2015_Street_Tree_Census_Tree_Data.csv.txt                   0            0
# 311_Service_Requests_for_2009.csv.txt                       0            0
# ACS_Community_Partners.csv.txt                              0            0
# ...                                                       ...          ...
# Voting_Poll_Sites.csv.txt                                   0            0
# Water_Consumption_And_Cost__2013_-_2020_.csv.txt            0            0
# Wholesale_Markets.csv.txt                                   0            0
# WiredNYC___All_Buildings_Data.csv.txt                       0            0
# Workforce1_Job_Listing.csv.txt                              0            0
#
#                                                  zoning dist3 zoning distr 1  \
# 2010_2016_School_Safety_Report.csv.txt                      0              0
# 2015_Green_Taxi_Trip_Data.csv.txt                           0              0
# 2015_Street_Tree_Census_Tree_Data.csv.txt                   0              0
# 311_Service_Requests_for_2009.csv.txt                       0              0
# ACS_Community_Partners.csv.txt                              0              0
# ...                                                       ...            ...
# Voting_Poll_Sites.csv.txt                                   0              0
# Water_Consumption_And_Cost__2013_-_2020_.csv.txt            0              0
# Wholesale_Markets.csv.txt                                   0              0
# WiredNYC___All_Buildings_Data.csv.txt                       0              0
# Workforce1_Job_Listing.csv.txt                              0              0
#
#                                                  zoning distr 2  \
# 2010_2016_School_Safety_Report.csv.txt                        0
# 2015_Green_Taxi_Trip_Data.csv.txt                             0
# 2015_Street_Tree_Census_Tree_Data.csv.txt                     0
# 311_Service_Requests_for_2009.csv.txt                         0
# ACS_Community_Partners.csv.txt                                0
# ...                                                         ...
# Voting_Poll_Sites.csv.txt                                     0
# Water_Consumption_And_Cost__2013_-_2020_.csv.txt              0
# Wholesale_Markets.csv.txt                                     0
# WiredNYC___All_Buildings_Data.csv.txt                         0
# Workforce1_Job_Listing.csv.txt                                0
#
#                                                  zoning distr 3  \
# 2010_2016_School_Safety_Report.csv.txt                        0
# 2015_Green_Taxi_Trip_Data.csv.txt                             0
# 2015_Street_Tree_Census_Tree_Data.csv.txt                     0
# 311_Service_Requests_for_2009.csv.txt                         0
# ACS_Community_Partners.csv.txt                                0
# ...                                                         ...
# Voting_Poll_Sites.csv.txt                                     0
# Water_Consumption_And_Cost__2013_-_2020_.csv.txt              0
# Wholesale_Markets.csv.txt                                     0
# WiredNYC___All_Buildings_Data.csv.txt                         0
# Workforce1_Job_Listing.csv.txt                                0
#
#                                                  zoning district
# 2010_2016_School_Safety_Report.csv.txt                         0
# 2015_Green_Taxi_Trip_Data.csv.txt                              0
# 2015_Street_Tree_Census_Tree_Data.csv.txt                      0
# 311_Service_Requests_for_2009.csv.txt                          0
# ACS_Community_Partners.csv.txt                                 0
# ...                                                          ...
# Voting_Poll_Sites.csv.txt                                      0
# Water_Consumption_And_Cost__2013_-_2020_.csv.txt               0
# Wholesale_Markets.csv.txt                                      0
# WiredNYC___All_Buildings_Data.csv.txt                          0
# Workforce1_Job_Listing.csv.txt                                 0
#
# [138 rows x 1931 columns]

# %%
#As you can see there are some different column names which contain the same information such as "zip" and "zip code"
df_names.sum().sort_values(ascending=False)[:50]
# Out:
# latitude              94.0
# longitude             94.0
# borough               91.0
# bin                   78.0
# community board       70.0
# nta                   68.0
# bbl                   68.0
# census tract          64.0
# postcode              58.0
# council district      53.0
# city                  35.0
# address               28.0
# state                 27.0
# lot                   26.0
# block                 25.0
# street                21.0
# location              19.0
# status                16.0
# boro                  14.0
# phone                 14.0
# zip                   14.0
# street name           13.0
# number                11.0
# location 1            11.0
# name                  10.0
# zip code              10.0
# council district       8.0
# email                  8.0
# street address         8.0
# expiration date        7.0
# account name           7.0
# jurisdiction_code      7.0
# agency                 7.0
# description            6.0
# comments               6.0
# building               6.0
# community council      6.0
# application type       5.0
# created                5.0
# effective date         5.0
# website                5.0
# export date            5.0
# hours                  5.0
# buildingid             5.0
# business name          5.0
# housenumber            5.0
# trade name             5.0
# renewal                5.0
# type                   5.0
# y_coord_cd             5.0
# dtype: float64

# %% [markdown]
# # Part2 search word from columns

# %%
def search_words(words):
    names = []
    for name in df_names.columns:
        if words.lower() in name.lower():
            names.append(name)
    filenames = {}
    counter = 0
    for name in names:
        indexlist = list(df_names[df_names[name] == 1].index)
        filenames[name]  = indexlist
        counter += len(indexlist)
    print("Number of columns containing this words: " + str(counter))     
    return filenames

# %% [markdown]
# #

# %%
#simple count
temp = search_words("zip")
# Out:
# Number of columns containing this words: 53

# %%
#more detailed result
temp
# Out:
# {'address zip': ['Legally_Operating_Businesses.csv.txt'],
#  'business zip': ['Consumer_Services_Mediated_Complaints.csv.txt'],
#  'city, state, zip ': ['Revised_Notice_of_Property_Value__RNOPV_.csv.txt'],
#  'complainant zip ': ['Consumer_Services_Mediated_Complaints.csv.txt'],
#  'eviction_zip': ['Evictions.csv.txt'],
#  'filing representative zip': ['DOB_NOW__Build___Job_Application_Filings.csv.txt'],
#  'garage_zip': ['Routes.csv.txt'],
#  'incident zip': ['311_Service_Requests_for_2009.csv.txt'],
#  'incident_address_zip': ['DOHMH_Indoor_Environmental_Complaints.csv.txt'],
#  'mailingzip': ['M_WBE__LBE__and_EBE_Certified_Business_List.csv.txt'],
#  'owner zip code': ['DOB_NOW_Build_Approved_Permits.csv.txt'],
#  'owner_zip': ['DOB_NOW__Safety___Facades_Compliance_Filings.csv.txt'],
#  'practice zip code': ['NYC_REACH_Members.csv.txt'],
#  'program zipcode': ['Department_for_the_Aging__DFTA__All_Contracted_Providers.csv.txt'],
#  'property disposed to zip': ['Deed_Restriction_Database.csv.txt'],
#  'qewi_zip': ['DOB_NOW__Safety___Facades_Compliance_Filings.csv.txt'],
#  'respondent_zip': ['DOB_ECB_Violations.csv.txt'],
#  'school zip': ['311_Service_Requests_for_2009.csv.txt'],
#  'zip': ['Buildings_Subject_to_HPD_Jurisdiction.csv.txt',
#   'Charges.csv.txt',
#   'DOB_Job_Application_Filings.csv.txt',
#   'DOB_NOW__Build___Job_Application_Filings.csv.txt',
#   'Housing_Maintenance_Code_Complaints.csv.txt',
#   'IDNYC_Locations.csv.txt',
#   'Inspections.csv.txt',
#   'License_Applications.csv.txt',
#   'M_WBE__LBE__and_EBE_Certified_Business_List.csv.txt',
#   'Multiple_Dwelling_Registrations.csv.txt',
#   'NYC_Council_Constituent_Services.csv.txt',
#   'Open_Market_Order__OMO__Charges.csv.txt',
#   'Sidewalk_Cafe__Licenses_and_Applications.csv.txt',
#   'Transportation_Sites.csv.txt'],
#  'zip \ncode': ['Recognized_Shop_Healthy_Stores.csv.txt'],
#  'zip code': ['DOB_Cellular_Antenna_Filings.csv.txt',
#   'DOB_Complaints_Received.csv.txt',
#   'Greenbook.csv.txt',
#   'Motor_Vehicle_Collisions_Crashes.csv.txt',
#   'Natural_Gas_Consumption_by_ZIPCode_-_2010.csv.txt',
#   'New_York_City_Council_Discretionary_Funding__2013_.csv.txt',
#   'New_York_City_Locations_Providing_Seasonal_Flu_Vaccinations.csv.txt',
#   'NYC_Citywide_Annualized_Calendar_Sales_Update.csv.txt',
#   'Real_Property_Income_and_Expense_Form_non-compliance_list.csv.txt',
#   'Tax_Lien_Sale_Lists.csv.txt'],
#  'zip_city': ['2015_Street_Tree_Census_Tree_Data.csv.txt'],
#  'zip_code': ['Asbestos_Control_Program__ACP7_.csv.txt',
#   'DSNY_Graffiti_Tracking.csv.txt',
#   'Incidents_Responded_to_by_Fire_Companies.csv.txt',
#   'Rodent_Inspection.csv.txt'],
#  'zipcode': ['DOHMH_Childcare_Center_Inspections.csv.txt',
#   'DOHMH_Dog_Bite_Data.csv.txt',
#   'DOHMH_New_York_City_Restaurant_Inspection_Results.csv.txt',
#   'Mobile_Telecommunications_Franchise_Pole_Reservation_Locations.csv.txt'],
#  'zipcode(s)': ['Film_Permits.csv.txt']}

# %%
#get the json file from certain filename
def json_from_filename(filename):
    return djson[filenames.index(filename)]

# %%
def get_result(word):
    temp = search_words(word)
    info = []

    for key in temp:
        values = temp[key]
        for filename in values:
            jsoncontent = json_from_filename(filename)
            for i in jsoncontent["columns"]:
                if i["name"].lower()  == key:
                    info.append((i,filename))
    keys = []
    for dict_i,filename in info:
        for key in dict_i.keys():
            if key not in keys:
                keys.append(key)   
    result = pd.DataFrame(columns = keys)
    [None]*len(result.columns)
    for dict_i,filename in info:
        result.loc[filename] = [None]*len(result.columns)
        for key in dict_i.keys():
            if key in result.columns:
                result.loc[filename][key] = dict_i[key]
    print("Number of files which have columns containing this words: " + str(len(result)))
    print("Number of all files:" + str(len(filenames)))
    result.to_csv(word+".csv")
    return result

# %%
result = get_result("zip")
# Out:
# Number of columns containing this words: 53
# Number of files which have columns containing this words: 48
# Number of all files:138

# %%
result = get_result("latitude")
# Out:
# Number of columns containing this words: 98
# Number of files which have columns containing this words: 96
# Number of all files:138

# %%
#count the number of dataset which contains lat lon based on semantic types
counter = 0
djson = []
filenames = []
for root,dirs,files in os.walk(resultDirectory):
    for file in files:
        if file.endswith(".txt"):
            with open("result/" + file) as f:
                tempdjson = json.load(f)
                djson.append(tempdjson) 
                filenames.append(file) #match filename with djson content
def check_lat(col_list):
    for content in col_list:
        if 'semantic_types' in content:
            if content['semantic_types'] ==['http://schema.org/latitude']:
                return True
    return False
def check_lon(col_list):
    for content in col_list:
        if 'semantic_types' in content:
            if content['semantic_types'] ==['http://schema.org/longitude']:
                return True
    return False
num_data = len(djson)
counter = 0
latlon_data = pd.DataFrame({'latlon' : []})
for i in range(num_data):
    if check_lat(djson[i]["columns"]) and check_lon(djson[i]["columns"]):
        counter +=1
        latlon_data.loc[filenames[i]] = [1]
    elif check_lat(djson[i]["columns"]) or check_lon(djson[i]["columns"]):
        print(djson[i])
    else:
        latlon_data.loc[filenames[i]] = [0]
        
counter
# Out:
# 94

# %%
def get_positive(words_list):
    positive = []
    for words in words_list:
        temp = search_words(words)
        for i in temp:
            for j in temp[i]:
                #print(j)
                positive.append(j.split(".txt")[0])
    return positive

# %%
len(get_positive(["latitude"]))
# Out:
# Number of columns containing this words: 98
# 98

# %%
positive = get_positive(["zip"])
# Out:
# Number of columns containing this words: 53

# %%
search_words("zip")
# Out:
# Number of columns containing this words: 53
# {'address zip': ['Legally_Operating_Businesses.csv.txt'],
#  'business zip': ['Consumer_Services_Mediated_Complaints.csv.txt'],
#  'city, state, zip ': ['Revised_Notice_of_Property_Value__RNOPV_.csv.txt'],
#  'complainant zip ': ['Consumer_Services_Mediated_Complaints.csv.txt'],
#  'eviction_zip': ['Evictions.csv.txt'],
#  'filing representative zip': ['DOB_NOW__Build___Job_Application_Filings.csv.txt'],
#  'garage_zip': ['Routes.csv.txt'],
#  'incident zip': ['311_Service_Requests_for_2009.csv.txt'],
#  'incident_address_zip': ['DOHMH_Indoor_Environmental_Complaints.csv.txt'],
#  'mailingzip': ['M_WBE__LBE__and_EBE_Certified_Business_List.csv.txt'],
#  'owner zip code': ['DOB_NOW_Build_Approved_Permits.csv.txt'],
#  'owner_zip': ['DOB_NOW__Safety___Facades_Compliance_Filings.csv.txt'],
#  'practice zip code': ['NYC_REACH_Members.csv.txt'],
#  'program zipcode': ['Department_for_the_Aging__DFTA__All_Contracted_Providers.csv.txt'],
#  'property disposed to zip': ['Deed_Restriction_Database.csv.txt'],
#  'qewi_zip': ['DOB_NOW__Safety___Facades_Compliance_Filings.csv.txt'],
#  'respondent_zip': ['DOB_ECB_Violations.csv.txt'],
#  'school zip': ['311_Service_Requests_for_2009.csv.txt'],
#  'zip': ['Buildings_Subject_to_HPD_Jurisdiction.csv.txt',
#   'Charges.csv.txt',
#   'DOB_Job_Application_Filings.csv.txt',
#   'DOB_NOW__Build___Job_Application_Filings.csv.txt',
#   'Housing_Maintenance_Code_Complaints.csv.txt',
#   'IDNYC_Locations.csv.txt',
#   'Inspections.csv.txt',
#   'License_Applications.csv.txt',
#   'M_WBE__LBE__and_EBE_Certified_Business_List.csv.txt',
#   'Multiple_Dwelling_Registrations.csv.txt',
#   'NYC_Council_Constituent_Services.csv.txt',
#   'Open_Market_Order__OMO__Charges.csv.txt',
#   'Sidewalk_Cafe__Licenses_and_Applications.csv.txt',
#   'Transportation_Sites.csv.txt'],
#  'zip \ncode': ['Recognized_Shop_Healthy_Stores.csv.txt'],
#  'zip code': ['DOB_Cellular_Antenna_Filings.csv.txt',
#   'DOB_Complaints_Received.csv.txt',
#   'Greenbook.csv.txt',
#   'Motor_Vehicle_Collisions_Crashes.csv.txt',
#   'Natural_Gas_Consumption_by_ZIPCode_-_2010.csv.txt',
#   'New_York_City_Council_Discretionary_Funding__2013_.csv.txt',
#   'New_York_City_Locations_Providing_Seasonal_Flu_Vaccinations.csv.txt',
#   'NYC_Citywide_Annualized_Calendar_Sales_Update.csv.txt',
#   'Real_Property_Income_and_Expense_Form_non-compliance_list.csv.txt',
#   'Tax_Lien_Sale_Lists.csv.txt'],
#  'zip_city': ['2015_Street_Tree_Census_Tree_Data.csv.txt'],
#  'zip_code': ['Asbestos_Control_Program__ACP7_.csv.txt',
#   'DSNY_Graffiti_Tracking.csv.txt',
#   'Incidents_Responded_to_by_Fire_Companies.csv.txt',
#   'Rodent_Inspection.csv.txt'],
#  'zipcode': ['DOHMH_Childcare_Center_Inspections.csv.txt',
#   'DOHMH_Dog_Bite_Data.csv.txt',
#   'DOHMH_New_York_City_Restaurant_Inspection_Results.csv.txt',
#   'Mobile_Telecommunications_Franchise_Pole_Reservation_Locations.csv.txt'],
#  'zipcode(s)': ['Film_Permits.csv.txt']}

# %%
positive
# Out:
# ['Legally_Operating_Businesses.csv',
#  'Consumer_Services_Mediated_Complaints.csv',
#  'Revised_Notice_of_Property_Value__RNOPV_.csv',
#  'Consumer_Services_Mediated_Complaints.csv',
#  'Evictions.csv',
#  'DOB_NOW__Build___Job_Application_Filings.csv',
#  'Routes.csv',
#  '311_Service_Requests_for_2009.csv',
#  'DOHMH_Indoor_Environmental_Complaints.csv',
#  'M_WBE__LBE__and_EBE_Certified_Business_List.csv',
#  'DOB_NOW_Build_Approved_Permits.csv',
#  'DOB_NOW__Safety___Facades_Compliance_Filings.csv',
#  'NYC_REACH_Members.csv',
#  'Department_for_the_Aging__DFTA__All_Contracted_Providers.csv',
#  'Deed_Restriction_Database.csv',
#  'DOB_NOW__Safety___Facades_Compliance_Filings.csv',
#  'DOB_ECB_Violations.csv',
#  '311_Service_Requests_for_2009.csv',
#  'Buildings_Subject_to_HPD_Jurisdiction.csv',
#  'Charges.csv',
#  'DOB_Job_Application_Filings.csv',
#  'DOB_NOW__Build___Job_Application_Filings.csv',
#  'Housing_Maintenance_Code_Complaints.csv',
#  'IDNYC_Locations.csv',
#  'Inspections.csv',
#  'License_Applications.csv',
#  'M_WBE__LBE__and_EBE_Certified_Business_List.csv',
#  'Multiple_Dwelling_Registrations.csv',
#  'NYC_Council_Constituent_Services.csv',
#  'Open_Market_Order__OMO__Charges.csv',
#  'Sidewalk_Cafe__Licenses_and_Applications.csv',
#  'Transportation_Sites.csv',
#  'Recognized_Shop_Healthy_Stores.csv',
#  'DOB_Cellular_Antenna_Filings.csv',
#  'DOB_Complaints_Received.csv',
#  'Greenbook.csv',
#  'Motor_Vehicle_Collisions_Crashes.csv',
#  'Natural_Gas_Consumption_by_ZIPCode_-_2010.csv',
#  'New_York_City_Council_Discretionary_Funding__2013_.csv',
#  'New_York_City_Locations_Providing_Seasonal_Flu_Vaccinations.csv',
#  'NYC_Citywide_Annualized_Calendar_Sales_Update.csv',
#  'Real_Property_Income_and_Expense_Form_non-compliance_list.csv',
#  'Tax_Lien_Sale_Lists.csv',
#  '2015_Street_Tree_Census_Tree_Data.csv',
#  'Asbestos_Control_Program__ACP7_.csv',
#  'DSNY_Graffiti_Tracking.csv',
#  'Incidents_Responded_to_by_Fire_Companies.csv',
#  'Rodent_Inspection.csv',
#  'DOHMH_Childcare_Center_Inspections.csv',
#  'DOHMH_Dog_Bite_Data.csv',
#  'DOHMH_New_York_City_Restaurant_Inspection_Results.csv',
#  'Mobile_Telecommunications_Franchise_Pole_Reservation_Locations.csv',
#  'Film_Permits.csv']

# %%
with open("data/metadata.json") as f:
     actual = json.load(f)
def get_acc(subwords, words):
    positive = get_positive(subwords)

    TP = 0
    TN = 0
    FP = 0
    FN = 0
    for file in filenames:  
        file2 = file.split(".txt")[0].replace("-","_").replace("___","_").replace("__","_").replace("_.csv",".csv").replace("NYPD_Shooting_Incident_Data_Historic.csv","NYPD_Shooting_Incident_Data_Historic_.csv")
        a = 0
        b = 0
        for i in actual[file2]["attributes"]:
            if(actual[file2]["attributes"][i]["type"]) == words:
                a = 1
            if file.split(".txt")[0] in positive:
                b = 1
        if a == 1 and b== 1:
            TP +=1
        elif a == 0 and b == 0:
            TN +=1
        elif a == 1 and b == 0:
            FN+=1
        elif a == 0 and b ==1:
            FP +=1
            print("FP: "+ file)
    print("TP"+str(TP))
    print("TN"+str(TN))
    print("FP"+str(FP))
    print("FN"+str(FN))
    print("Acc: "+str(a))
    print("Recall: "+str(TP/(TP+FN)))

# %%
get_acc(["latitude"],"latitude")
#some can be identified from column name directly
# Out:
# Number of columns containing this words: 98
# TP96
# TN42
# FP0
# FN0
# Acc: 1.0
# Recall: 1.0

# %%
get_acc(["zip","post"],"zipcode")
# Out:
# Number of columns containing this words: 53
# Number of columns containing this words: 62
# FP: Deed_Restriction_Database.csv.txt
# FP: DOB_ECB_Violations.csv.txt
# FP: Parking_Violations_Issued_-_Fiscal_Year_2015.csv.txt
# FP: Recognized_Shop_Healthy_Stores.csv.txt
# TP103
# TN31
# FP4
# FN0
# Acc: 0.9710144927536232
# Recall: 1.0

# %%
t = pd.read_csv(dataDirectory + "/Parking_Violations_Issued_-_Fiscal_Year_2015-011.csv")
# Out:
# /Users/Xianbo/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (18,29,38,40,41,42) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
t["Violation Post Code"]
# Out:
# 0           A 17
# 1           09 6
# 2            001
# 3           01 3
# 4           M 42
#             ...
# 11809228    12 7
# 11809229    14 3
# 11809230    C 77
# 11809231    99 6
# 11809232    70 1
# Name: Violation Post Code, Length: 11809233, dtype: object

# %%
get_acc(["zip","post"],"zipcode")
#some has errors. For example, a column named "Property Disposed to ZIP" is not ZIP
#need to identify other features
# Out:
# Number of columns containing this words: 53
# Number of columns containing this words: 62
# FP: Parking_Violations_Issued_-_Fiscal_Year_2015.csv
# FP: Parking_Violations_Issued_-_Fiscal_Year_2015.csv
# FP: Parking_Violations_Issued_-_Fiscal_Year_2015.csv
# FP: Parking_Violations_Issued_-_Fiscal_Year_2015.csv
# TP103
# TN31
# FP4
# FN0
# Acc: 0.9710144927536232
# Recall: 1.0

# %%
positive = get_positive(["zip","post"])
temp = search_words("zip")
temp
for filename in positive:
    for key in temp:
        for names in temp[key]:
            if names == filename+".txt":
                jfile = json_from_filename(filename+".txt")
                print(key)
                for i in jfile["columns"]:
                    if i["name"] == key:
                        print(i["structural_type"] == 'http://schema.org/Integer')
# Out:
# Number of columns containing this words: 53
# Number of columns containing this words: 62
# Number of columns containing this words: 53
# address zip
# business zip
# complainant zip
# city, state, zip
# business zip
# complainant zip
# eviction_zip
# filing representative zip
# zip
# garage_zip
# incident zip
# school zip
# incident_address_zip
# mailingzip
# zip
# owner zip code
# owner_zip
# qewi_zip
# practice zip code
# program zipcode
# property disposed to zip
# owner_zip
# qewi_zip
# respondent_zip
# incident zip
# school zip
# zip
# zip
# zip
# filing representative zip
# zip
# zip
# zip
# True
# zip
# zip
# mailingzip
# zip
# zip
# zip
# zip
# zip
# zip
# zip
# code
# zip code
# zip code
# zip code
# zip code
# zip code
# zip code
# zip code
# zip code
# zip code
# zip code
# zip_city
# False
# zip_code
# zip_code
# zip_code
# zip_code
# zipcode
# zipcode
# zipcode
# zipcode
# zipcode(s)
# property disposed to zip
# zip_city
# False
# city, state, zip

# %%
get_acc(["city"],"city")
#FP because of name of electricity
# Out:
# Number of columns containing this words: 68
# FP: 2015_Street_Tree_Census_Tree_Data.csv.txt
# FP: Deed_Restriction_Database.csv.txt
# FP: DOB_Job_Application_Filings.csv.txt
# FP: DOHMH_Childcare_Center_Inspections.csv.txt
# FP: DOHMH_Cooling_Tower_Data.csv.txt
# FP: DSNY_Graffiti_Tracking.csv.txt
# FP: Energy_and_Water_Data_Disclosure_for_Local_Law_84_2017__Data_for_Calendar_Year_2016_.csv.txt
# FP: Financial_Empowerment_Centers.csv.txt
# FP: HIV_AIDS_Diagnoses_by_Neighborhood__Sex__and_Race_Ethnicity.csv.txt
# FP: Real_Property_Income_and_Expense_Form_non-compliance_list.csv.txt
# FP: Revised_Notice_of_Property_Value__RNOPV_.csv.txt
# FP: Shelter_Repair_Scorecard.csv.txt
# TP42
# TN83
# FP12
# FN1
# Acc: 0.9057971014492754
# Recall: 0.9767441860465116

# %%
get_acc(["zip","post"],"zipcode")
#FP because of name of electricity
# Out:
# Number of columns containing this words: 53
# Number of columns containing this words: 62
# FP: Deed_Restriction_Database.csv.txt
# FP: DOB_ECB_Violations.csv.txt
# FP: Parking_Violations_Issued_-_Fiscal_Year_2015.csv.txt
# FP: Recognized_Shop_Healthy_Stores.csv.txt
# TP103
# TN31
# FP4
# FN0
# Acc: 0.9710144927536232
# Recall: 1.0

# %%
get_acc(["address"],"address")
# Out:
# Number of columns containing this words: 96
# FP: Center___Service_Locations.csv.txt
# FP: Consumer_Services_Mediated_Complaints.csv.txt
# FP: Deed_Restriction_Database.csv.txt
# FP: Directory_Of_Job_Centers.csv.txt
# FP: Directory_of_SNAP_Centers.csv.txt
# FP: DOHMH_Farmers_Markets.csv.txt
# FP: Energy_Efficiency_Projects.csv.txt
# FP: Latin_Cultural_Organizations.csv.txt
# FP: Legally_Operating_Businesses.csv.txt
# FP: LinkNYC_Locations.csv.txt
# FP: Local_Law_44_Disqualified_List.csv.txt
# FP: New_York_City_Council_Discretionary_Funding__2009-2013_.csv.txt
# FP: New_York_City_Council_Discretionary_Funding__2013_.csv.txt
# FP: NYC_Community_Based_Organizations.csv.txt
# FP: NYC_Service__Volunteer_Opportunities__Historical_.csv.txt
# FP: Routes.csv.txt
# FP: Transportation_Sites.csv.txt
# TP50
# TN69
# FP17
# FN2
# Acc: 0.8623188405797102
# Recall: 0.9615384615384616

# %%
get_acc(["state"],"state")
# Out:
# Number of columns containing this words: 43
# TP34
# TN100
# FP4
# FN0
# Acc: 0.9710144927536232
# Recall: 1.0

# %%
get_acc(["country"],"country")
# Out:
# Number of columns containing this words: 3
# TP3
# TN134
# FP0
# FN1
# Acc: 0.9927536231884058
# Recall: 0.75

# %%
get_acc(["boro"],"borough")
# Out:
# Number of columns containing this words: 152
# FP: Participatory_Budgeting_Projects.csv.txt
# FP: Street_Closures_due_to_construction_activities_by_Block.csv.txt
# TP118
# TN18
# FP2
# FN0
# Acc: 0.9855072463768116
# Recall: 1.0

# %%
"boro" in "Borough Description".lower()
# Out:
# True

# %%
temp = get_positive_detail(["zip"])
# Out:
# Number of columns containing this words: 53

# %%
"address" in temp
# Out:
# False

# %%
def get_positive_detail(words_list):
    positive = {}
    for words in words_list:
        temp = search_words2(words)
        for i in temp:
            for j in temp[i]:
                #print(j)
                positive[j.split(".txt")[0]] = i
    return positive

def search_words2(words):
    names = []
    for name in df_names.columns:
        if words.lower() in name.lower():
            names.append(name)
    filenames = {}
    counter = 0
    for name in names:
        indexlist = list(df_names[df_names[name] == 1].index)
        filenames[name]  = indexlist
        counter += len(indexlist)
    print("Number of columns containing this words: " + str(counter))     
    return filenames

def get_acc_zip(subwords, words):
    positive_detail = get_positive_detail(subwords)
    positive = get_positive(subwords)
    counter = 0
    TP = 0
    TN = 0
    FP = 0
    FN = 0
    for file in filenames:  
        file2 = file.split(".txt")[0].replace("-","_").replace("___","_").replace("__","_").replace("_.csv",".csv").replace("NYPD_Shooting_Incident_Data_Historic.csv","NYPD_Shooting_Incident_Data_Historic_.csv")
        a = 0
        b = 0
        for i in actual[file2]["attributes"]:
            if(actual[file2]["attributes"][i]["type"]) == words:
                a = 1
                col_name = positive_detail[file.split(".txt")[0]]
                data = json_from_filename(file)["columns"]
                for i in data:
                    if i["name"].lower() == col_name.lower():
                        try:
                            print(i["mean"])
                        except:
                            counter +=1
                            print(i)
                            print(file)
            if file.split(".txt")[0] in positive:
                b = 1
        if a == 1 and b== 1:
            TP +=1
        elif a == 0 and b == 0:
            TN +=1
        elif a == 1 and b == 0:
            FN+=1
        elif a == 0 and b ==1:
            FP +=1
    print(counter)
    print("TP"+str(TP))
    print("TN"+str(TN))
    print("FP"+str(FP))
    print("FN"+str(FN))
    print("Acc: "+str((TP+TN)/(TP+TN+FN+FP)))
    print("Recall: "+str(TP/(TP+FN)))

# %%
get_acc_zip(["zip","post"], "zipcode")
# Out:
# Number of columns containing this words: 53
# Number of columns containing this words: 62
# Number of columns containing this words: 53
# Number of columns containing this words: 62
# 10788.239261851733
# 10914.432032076984
# {'name': 'School Zip', 'structural_type': 'http://schema.org/Text', 'semantic_types': ['http://schema.org/Enumeration'], 'num_distinct_values': 150}
# 311_Service_Requests_for_2009.csv.txt
# {'name': 'School Zip', 'structural_type': 'http://schema.org/Text', 'semantic_types': ['http://schema.org/Enumeration'], 'num_distinct_values': 150}
# 311_Service_Requests_for_2009.csv.txt
# 10810.085889570551
# 10819.007674943567
# 10477.011785945431
# 10797.062819657549
# 10863.76923076923
# 10852.616210599237
# 10987.990777457342
# 10648.237302281217
# 10623.6986101788
# 10751.09756097561
# 10793.212036871693
# 11330.833333333334
# {'name': 'POSTCODE', 'structural_type': 'http://schema.org/Text', 'semantic_types': ['http://schema.org/Enumeration'], 'missing_values_ratio': 0.00033886229157796874, 'num_distinct_values': 496}
# Construction_Demolition_Registrants.csv.txt
# 12671.064156206416
# 10872.08354755784
# 10474.600961538461
# 10758.47899159664
# 10692.8
# 10757.25
# {'name': 'Zip Code', 'structural_type': 'http://schema.org/Text', 'semantic_types': ['http://schema.org/Enumeration'], 'missing_values_ratio': 0.01660364951504192, 'num_distinct_values': 448}
# DOB_Cellular_Antenna_Filings.csv.txt
# 10566.430214883438
# {'name': 'ZIP Code', 'structural_type': 'http://schema.org/Text', 'semantic_types': ['http://schema.org/Enumeration'], 'missing_values_ratio': 3.054153190215715e-06, 'num_distinct_values': 222}
# DOB_Complaints_Received.csv.txt
# 595726.6069062166
# 333218.5597314426
# 333218.5597314426
# 232292.55789852465
# 232292.55789852465
# 366944.20277111646
# 10027.80574912892
# 10812.636268757104
# 10304.212305720237
# 10871.202574881765
# 10693.598590860163
# 10675.864095309782
# 10817.31536868468
# 10761.55
# 10438.736339132565
# 10564.422760770974
# 10569.94541071121
# 385059.0540126086
# 10732.871035940803
# 10792.167802230932
# 10728.962317330965
# 10783.774647887323
# {'name': 'ZipCode(s)', 'structural_type': 'http://schema.org/Text', 'semantic_types': ['http://schema.org/Enumeration'], 'num_distinct_values': 5046}
# Film_Permits.csv.txt
# 10648.826086956522
# 10786.098360655738
# 10537.999586947542
# 10724.143445033435
# 10769.660878819279
# 10769.01292273852
# 10497.037313432837
# 12693.312403750773
# 10786.63617720155
# 10805.537628586897
# 10255.385542168675
# 11531.425656673604
# 11488.716323396298
# 10402.334403424291
# 11455.422680412372
# 11994.6327391221
# 11994.6327391221
# 10521.389096544808
# 10833.61962610431
# 10942.866099071207
# {'name': 'Zip Code', 'structural_type': 'http://schema.org/Text', 'semantic_types': [], 'num_distinct_values': 231}
# Natural_Gas_Consumption_by_ZIPCode_-_2010.csv.txt
# {'name': 'Postcode', 'structural_type': 'http://schema.org/Text', 'semantic_types': ['http://schema.org/Enumeration'], 'missing_values_ratio': 0.06544352994970279, 'num_distinct_values': 988}
# New_York_City_Council_Discretionary_Funding__2009-2013_.csv.txt
# {'name': 'Zip Code', 'structural_type': 'http://schema.org/Text', 'semantic_types': ['http://schema.org/Enumeration'], 'missing_values_ratio': 0.006394260761072988, 'num_distinct_values': 858}
# New_York_City_Council_Discretionary_Funding__2013_.csv.txt
# 10674.366101694915
# 10765.131459279044
# 13627.645161290322
# 10775.02386585883
# 10754.47435897436
# 10705.216783216783
# 10758.6
# 10784.845320197044
# 10482.047040971169
# 10535.245555890328
# 10640.27027027027
# 10601.874285714286
# 10818.062661239868
# 10613.804135403943
# 10851.188891116904
# 10842.111940298508
# 11377.485294117647
# 10750.1915683847
# 10577.204469423257
# 10576.465630584918
# 10928.07481423103
# 10766.119691119691
# {'name': 'POSTCODE', 'structural_type': 'http://schema.org/Text', 'semantic_types': ['http://schema.org/Enumeration'], 'missing_values_ratio': 0.00011921742277478551, 'num_distinct_values': 236}
# Self_Hauler_Registrants.csv.txt
# 10350.968861209964
# 10465.762645043556
# 10992.490858651692
# 10963.333333333334
# 10515.432432432432
# 11098.25
# {'name': 'POSTCODE', 'structural_type': 'http://schema.org/Text', 'semantic_types': ['http://schema.org/Enumeration'], 'num_distinct_values': 103}
# Trade_Waste_Broker_Registrants.csv.txt
# {'name': 'POSTCODE', 'structural_type': 'http://schema.org/Text', 'semantic_types': ['http://schema.org/Enumeration'], 'missing_values_ratio': 0.0020037039516254992, 'num_distinct_values': 256}
# Trade_Waste_Hauler_Licensees.csv.txt
# 10762.572702242034
# 10889.529442970823
# 10814.162733930025
# {'name': 'POSTCODE', 'structural_type': 'http://schema.org/Text', 'semantic_types': ['http://schema.org/Enumeration'], 'missing_values_ratio': 0.002298554486639652, 'num_distinct_values': 67}
# Wholesale_Markets.csv.txt
# 13
# TP103
# TN31
# FP4
# FN0
# Acc: 0.9710144927536232
# Recall: 1.0

# %%
df = pd.read_csv(dataDirectory+"/311_Service_Requests_for_2009.csv")
# Out:
# /Users/Xianbo/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (8,46,47,48) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df.columns
# Out:
# Index(['Unique Key', 'Created Date', 'Closed Date', 'Agency', 'Agency Name',
#        'Complaint Type', 'Descriptor', 'Location Type', 'Incident Zip',
#        'Incident Address', 'Street Name', 'Cross Street 1', 'Cross Street 2',
#        'Intersection Street 1', 'Intersection Street 2', 'Address Type',
#        'City', 'Landmark', 'Facility Type', 'Status', 'Due Date',
#        'Resolution Action Updated Date', 'Community Board', 'Borough',
#        'X Coordinate (State Plane)', 'Y Coordinate (State Plane)',
#        'Park Facility Name', 'Park Borough', 'School Name', 'School Number',
#        'School Region', 'School Code', 'School Phone Number', 'School Address',
#        'School City', 'School State', 'School Zip', 'School Not Found',
#        'School or Citywide Complaint', 'Vehicle Type', 'Taxi Company Borough',
#        'Taxi Pick Up Location', 'Bridge Highway Name',
#        'Bridge Highway Direction', 'Road Ramp', 'Bridge Highway Segment',
#        'Garage Lot Name', 'Ferry Direction', 'Ferry Terminal Name', 'Latitude',
#        'Longitude', 'Location'],
#       dtype='object')

# %%
df["School Zip"]
# Out:
# 0                10033
# 1          Unspecified
# 2          Unspecified
# 3          Unspecified
# 4          Unspecified
#               ...
# 1783128    Unspecified
# 1783129    Unspecified
# 1783130    Unspecified
# 1783131    Unspecified
# 1783132    Unspecified
# Name: School Zip, Length: 1783133, dtype: object
